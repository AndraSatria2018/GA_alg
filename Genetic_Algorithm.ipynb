# %% [markdown]
# <a href="https://colab.research.google.com/github/AndraSatria2018/GA_alg/blob/main/Genetic_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Nama : Andra Satria Hermawan
#Nim : A11.2018.11194
#Kelompok : A11.4624

# %%
import numpy as np
import math 
import random

# %%
class Algoritma_genetika :

#Pembentukan Chromosom : 

	jum_chrom = 6 #jumlah chromosome
	gen = ["a", "b", "c", "d"] #nilai gen abcd
	nilai_per_gen = {
		'min' : 0,
		'max' : 10
	} #nilai per gen 0-10
    
	crossover_rate = 50/100 #persen
	mutasi_rate = 10/100 #persen
	total_gen = 24
# total_gen     = (jumlah gen dalam chromosome) * jumlah populasi
# = 4 * 6
# = 24
	next_gen = np.arange(4)
	stop = False

#inisialisasi chromosome secara random    

	def __init__(self):
		self.first_chrom = np.random.randint(low=self.nilai_per_gen['min'], high=self.nilai_per_gen['max'], size=(self.jum_chrom, len(self.gen)))
		print("==================================================inisialisasi=================================================")
		print(self.first_chrom)
		print("---------------------------------------------------------------------------------------------------------------")

#evaluasi chromosome
	def evaluasi_chrom(self, chrom, generasi):
		# mencari fungsi objektif
		# fungsi_objektif(chromosome) = | (a+2b+3c+4d) – 30 |
		print("GENERASI ["+str(generasi)+"] ------")
		
		jum_chromo = len(chrom)
		o = np.arange(jum_chromo)   
		fitness = np.arange(jum_chromo, dtype='f')
		
		for x in range(len(chrom)):
		
			#FUNGSI OBJEKTIF 
			#fo=fungsi_objektif(chromosome[x])=o[x]
			fo = abs((chrom[x][0]+2*chrom[x][1]+3*chrom[x][2]+4*chrom[x][3])-30)
			o[x] = fo
			
			#SELEKSI CHROMOSOME, DAN MENCARI FITNESS
			fitn = 1/(fo+1)
			
			fitness[x] = fitn
			if(fitn == 1):
				self.stop = True
			print("CHROMOSOME {0} : {1}, fitness = {2}".format(x, np.array2string(chrom[x], separator=','), fitn))
		print("FITNESS SELESAI!!")
		print(o)
		
        
#probabilitas
		Probab = np.arange(jum_chromo, dtype='f')
		# print(fitness)
		total_fitness = fitness.sum() #rumus total fitness
		Probab = fitness / total_fitness #rumus mencari probabilitas
		print("Total fitness : {}".format(str(total_fitness)))
		print("Rata-rata fitness : {}".format(str(np.average(fitness))))
		print("Probabilitas : {}".format(np.array2string(Probab, separator=',')))
		print("Probabilitas Paling Tinggi : {}, Pada chromosome ke {}".format(Probab[Probab.argmax()], str(Probab.argmax())))
		print("CHROMOSOME YANG MUNGKIN TERPILIH : {}".format(np.array2string(chrom[Probab.argmax()], separator=',')))
		print("")
		print("")
		self.next_gen = chrom[Probab.argmax()]

#seleksi dengan ROULETE WHELL (C) dari cumulative probabilitas
		C = np.arange(jum_chromo, dtype='f')
		total_x = 0
		for x in range(len(Probab)):
			total_x += Probab[x]
			C[x] = total_x

#putar roulete whell sebanyak jumlah populasi yaitu 6 kali secara acak
		R = np.random.sample(len(fitness))
		chrom_baru = np.arange(jum_chromo*len(self.gen)).reshape(jum_chromo, len(self.gen))


#RUMUS UNTUK MENCARI CHROMOSOME BARU BERDASARKAN ROULETE WHELL
		for y in range(len(R)):
			for k in range(len(chrom_baru)):
				if(R[y] < C[0]):
					chrom_baru[y] = chrom[0]
				elif((C[k-1] < R[y]) & (R[y] < C[k])):
					chrom_baru[y] = chrom[k]

#MENCARI CROSSOVER chromosome
		R = np.random.sample(jum_chromo)
		index_chrom_parent = [] # [1,2,3, ...]
		for p in range(len(R)):
			if(R[p] < self.crossover_rate):
				index_chrom_parent.append(p)
                
#menentukan posisi crossover
		#membangkitkan bilangan acak dengan batasan 1 sampai (panjang chromosome-1), dalam kasus ini bilangan acak yang dibangkitkan adalah 1 – 3.
		posisi_cros = np.random.randint(low=1, high=len(self.gen), size=len(index_chrom_parent))

#menentukan posisi cut-point crossover
		offspring = np.arange(len(self.gen)*len(index_chrom_parent)).reshape(len(index_chrom_parent), len(self.gen))
		for i_parent in range(len(index_chrom_parent)):
			index_chrome_1 = index_chrom_parent[i_parent]
			if(i_parent == len(index_chrom_parent)-1):
				index_chrome_2 = index_chrom_parent[0]
			else:
				index_chrome_2 = index_chrom_parent[i_parent+1]
			#melakukan cut-point
			cut_point = posisi_cros[i_parent]
			for p in range(len(chrom_baru[index_chrome_1])):
				#LOOPING BERDASARKAN GEN
				if(p >= posisi_cros[i_parent]):
					#JIKA GEN[P] LEBIH BESAR ATAU SAMA DENGAN BILANGAN ACAK[P],
					#MAKA DIGANTI DGN CHROMOSOME KE-2
					offspring[i_parent][p] = chrom_baru[index_chrome_2][p]
				else:
					offspring[i_parent][p] = chrom_baru[index_chrome_1][p]

		#PROSES CROSSOVER DISIMPAN PADA VARIABLE 'OFFSPRING'
		#MELAKUKAN PENGGABUNGAN OFFSPRING DENGAN chrom_baru
		for x in range(len(offspring)):
			chrom_baru[index_chrom_parent[x]] = offspring[x]
            
#mutasi chromosome
# Misal mutation rate kita tentukan 10% maka diharapkan ada 10% dari total_gen yang mengalami populasi:
# jumlah mutasi      = 0.1 * 24
# = 2.4
# = 2

		total_gen = len(chrom) * len(chrom[0])
		jum_mutasi = self.mutasi_rate * total_gen #rumus menghitung jumlah mutasi
		jum_mutasi = int(jum_mutasi)

		random_i_mutasi = np.random.randint(low=0, high=total_gen, size=jum_mutasi)

		for x in range(len(random_i_mutasi)):
			index_mutasi = random_i_mutasi[x]
			byk_kromosom = len(chrom)
			byk_gen = len(chrom[0])
			random_value = random.randint(self.nilai_per_gen['min'], self.nilai_per_gen['max'])
			if(index_mutasi <= byk_gen):
				#jika index_mutasi <= banyak gen, maka akan mengganti
				#gen pada chromosome baru yang ke-0
				chrom_baru[0][index_mutasi-1]
			else:
				#POSISI Y DARI KROMOSOM, UNTUK MENCARI INDEX
				posisi_y = index_mutasi/byk_gen
				posisi_y = int(posisi_y)
				posisi_x = index_mutasi % byk_gen
				chrom_baru[posisi_y][posisi_x] = random_value
		return chrom_baru

	def do_now(self):
		chromosome_current = self.first_chrom
		for generasi in range(0, self.total_gen):
			if(self.stop != True):
				chromosome_current = self.evaluasi_chrom(chromosome_current, generasi)
		print("----------------------------------------------------------------------")
		print("ALL DONE!")
		print("CHROMOSOME TERTINGGI DAN TERBAIK ADALAH")
		print(self.next_gen)

run = Algoritma_genetika()
run.do_now()
# Out:
# ==================================================inisialisasi=================================================
# [[4 4 8 4]
#  [1 5 6 0]
#  [9 6 1 1]
#  [4 9 5 1]
#  [7 8 0 2]
#  [1 2 5 5]]
# ---------------------------------------------------------------------------------------------------------------
# GENERASI [0] ------
# CHROMOSOME 0 : [4,4,8,4], fitness = 0.043478260869565216
# CHROMOSOME 1 : [1,5,6,0], fitness = 0.5
# CHROMOSOME 2 : [9,6,1,1], fitness = 0.3333333333333333
# CHROMOSOME 3 : [4,9,5,1], fitness = 0.08333333333333333
# CHROMOSOME 4 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 5 : [1,2,5,5], fitness = 0.09090909090909091
# FITNESS SELESAI!!
# [22  1  2 11  1 10]
# Total fitness : 1.5510541
# Rata-rata fitness : 0.258509
# Probabilitas : [0.02803143,0.3223614 ,0.21490762,0.0537269 ,0.3223614 ,0.05861117]
# Probabilitas Paling Tinggi : 0.32236140966415405, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,5,6,0]
#
#
# GENERASI [1] ------
# CHROMOSOME 0 : [1,5,6,0], fitness = 0.5
# CHROMOSOME 1 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 2 : [1,5,6,2], fitness = 0.125
# CHROMOSOME 3 : [7,8,0,5], fitness = 0.07142857142857142
# CHROMOSOME 4 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 5 : [7,8,0,3], fitness = 0.16666666666666666
# FITNESS SELESAI!!
# [ 1  1  7 13  1  5]
# Total fitness : 1.8630952
# Rata-rata fitness : 0.31051585
# Probabilitas : [0.26837063,0.26837063,0.06709266,0.03833866,0.26837063,0.08945688]
# Probabilitas Paling Tinggi : 0.2683706283569336, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,5,6,0]
#
#
# GENERASI [2] ------
# CHROMOSOME 0 : [1,5,0,2], fitness = 0.08333333333333333
# CHROMOSOME 1 : [7,8,0,3], fitness = 0.16666666666666666
# CHROMOSOME 2 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 3 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 4 : [7,8,6,0], fitness = 0.08333333333333333
# CHROMOSOME 5 : [7,8,0,1], fitness = 0.25
# FITNESS SELESAI!!
# [11  5  1  1 11  3]
# Total fitness : 1.5833334
# Rata-rata fitness : 0.2638889
# Probabilitas : [0.05263158,0.10526316,0.31578946,0.31578946,0.05263158,0.15789473]
# Probabilitas Paling Tinggi : 0.31578946113586426, Pada chromosome ke 2
# CHROMOSOME YANG MUNGKIN TERPILIH : [7,8,0,2]
#
#
# GENERASI [3] ------
# CHROMOSOME 0 : [7,8,0,1], fitness = 0.25
# CHROMOSOME 1 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 2 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 3 : [10, 8, 0, 2], fitness = 0.2
# CHROMOSOME 4 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 5 : [7,8,0,2], fitness = 0.5
# FITNESS SELESAI!!
# [3 1 1 4 1 1]
# Total fitness : 2.45
# Rata-rata fitness : 0.40833333
# Probabilitas : [0.10204081,0.20408162,0.20408162,0.08163265,0.20408162,0.20408162]
# Probabilitas Paling Tinggi : 0.20408162474632263, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [7,8,0,2]
#
#
# GENERASI [4] ------
# CHROMOSOME 0 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 1 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 2 : [7,8,0,7], fitness = 0.045454545454545456
# CHROMOSOME 3 : [7,7,0,2], fitness = 0.5
# CHROMOSOME 4 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 5 : [7,8,0,2], fitness = 0.5
# FITNESS SELESAI!!
# [ 1  1 21  1  1  1]
# Total fitness : 2.5454545
# Rata-rata fitness : 0.4242424
# Probabilitas : [0.19642858,0.19642858,0.01785714,0.19642858,0.19642858,0.19642858]
# Probabilitas Paling Tinggi : 0.196428582072258, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [7,8,0,2]
#
#
# GENERASI [5] ------
# CHROMOSOME 0 : [7,7,0,2], fitness = 0.5
# CHROMOSOME 1 : [7,8,3,2], fitness = 0.09090909090909091
# CHROMOSOME 2 : [7,7,0,2], fitness = 0.5
# CHROMOSOME 3 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 4 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 5 : [7,8,0,2], fitness = 0.5
# FITNESS SELESAI!!
# [ 1 10  1  1  1  1]
# Total fitness : 2.590909
# Rata-rata fitness : 0.43181816
# Probabilitas : [0.19298247,0.03508772,0.19298247,0.19298247,0.19298247,0.19298247]
# Probabilitas Paling Tinggi : 0.19298246502876282, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [7,7,0,2]
#
#
# GENERASI [6] ------
# CHROMOSOME 0 : [7,7,0,2], fitness = 0.5
# CHROMOSOME 1 : [7,2,0,2], fitness = 0.08333333333333333
# CHROMOSOME 2 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 3 : [7,7,0,2], fitness = 0.5
# CHROMOSOME 4 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 5 : [7,8,0,2], fitness = 0.5
# FITNESS SELESAI!!
# [ 1 11  1  1  1  1]
# Total fitness : 2.5833333
# Rata-rata fitness : 0.43055555
# Probabilitas : [0.1935484 ,0.03225807,0.1935484 ,0.1935484 ,0.1935484 ,0.1935484 ]
# Probabilitas Paling Tinggi : 0.19354839622974396, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [7,7,0,2]
#
#
# GENERASI [7] ------
# CHROMOSOME 0 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 1 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 2 : [7,2,0,2], fitness = 0.08333333333333333
# CHROMOSOME 3 : [7,7,0,2], fitness = 0.5
# CHROMOSOME 4 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 5 : [7,8,0,3], fitness = 0.16666666666666666
# FITNESS SELESAI!!
# [ 1  1 11  1  1  5]
# Total fitness : 2.2500002
# Rata-rata fitness : 0.37500003
# Probabilitas : [0.2222222 ,0.2222222 ,0.03703703,0.2222222 ,0.2222222 ,0.07407407]
# Probabilitas Paling Tinggi : 0.2222221940755844, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [7,8,0,2]
#
#
# GENERASI [8] ------
# CHROMOSOME 0 : [7,7,0,2], fitness = 0.5
# CHROMOSOME 1 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 2 : [7,1,0,2], fitness = 0.07142857142857142
# CHROMOSOME 3 : [7,7,0,2], fitness = 0.5
# CHROMOSOME 4 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 5 : [7,4,0,2], fitness = 0.125
# FITNESS SELESAI!!
# [ 1  1 13  1  1  7]
# Total fitness : 2.1964285
# Rata-rata fitness : 0.36607143
# Probabilitas : [0.22764228,0.22764228,0.03252033,0.22764228,0.22764228,0.05691057]
# Probabilitas Paling Tinggi : 0.22764228284358978, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [7,7,0,2]
#
#
# GENERASI [9] ------
# CHROMOSOME 0 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 1 : [7,7,9,2], fitness = 0.037037037037037035
# CHROMOSOME 2 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 3 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 4 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 5 : [7,7,0,2], fitness = 0.5
# FITNESS SELESAI!!
# [ 1 26  1  1  1  1]
# Total fitness : 2.537037
# Rata-rata fitness : 0.4228395
# Probabilitas : [0.1970803 ,0.01459854,0.1970803 ,0.1970803 ,0.1970803 ,0.1970803 ]
# Probabilitas Paling Tinggi : 0.19708029925823212, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [7,8,0,2]
#
#
# GENERASI [10] ------
# CHROMOSOME 0 : [7,7,9,2], fitness = 0.037037037037037035
# CHROMOSOME 1 : [7,3,0,2], fitness = 0.1
# CHROMOSOME 2 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 3 : [4,8,0,2], fitness = 0.3333333333333333
# CHROMOSOME 4 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 5 : [7,8,0,2], fitness = 0.5
# FITNESS SELESAI!!
# [26  9  1  2  1  1]
# Total fitness : 1.9703704
# Rata-rata fitness : 0.32839507
# Probabilitas : [0.01879699,0.05075188,0.25375938,0.16917293,0.25375938,0.25375938]
# Probabilitas Paling Tinggi : 0.25375938415527344, Pada chromosome ke 2
# CHROMOSOME YANG MUNGKIN TERPILIH : [7,8,0,2]
#
#
# GENERASI [11] ------
# CHROMOSOME 0 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 1 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 2 : [7,8,5,2], fitness = 0.058823529411764705
# CHROMOSOME 3 : [2,8,0,2], fitness = 0.2
# CHROMOSOME 4 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 5 : [7,8,0,2], fitness = 0.5
# FITNESS SELESAI!!
# [ 1  1 16  4  1  1]
# Total fitness : 2.2588236
# Rata-rata fitness : 0.3764706
# Probabilitas : [0.22135416,0.22135416,0.02604167,0.08854166,0.22135416,0.22135416]
# Probabilitas Paling Tinggi : 0.2213541567325592, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [7,8,0,2]
#
#
# GENERASI [12] ------
# CHROMOSOME 0 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 1 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 2 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 3 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 4 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 5 : [2,3,0,2], fitness = 0.06666666666666667
# FITNESS SELESAI!!
# [ 1  1  1  1  1 14]
# Total fitness : 2.5666666
# Rata-rata fitness : 0.42777777
# Probabilitas : [0.1948052 ,0.1948052 ,0.1948052 ,0.1948052 ,0.1948052 ,0.02597403]
# Probabilitas Paling Tinggi : 0.19480520486831665, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [7,8,0,2]
#
#
# GENERASI [13] ------
# CHROMOSOME 0 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 1 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 2 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 3 : [7,8,7,2], fitness = 0.043478260869565216
# CHROMOSOME 4 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 5 : [7,8,0,2], fitness = 0.5
# FITNESS SELESAI!!
# [ 1  1  1 22  1  1]
# Total fitness : 2.5434783
# Rata-rata fitness : 0.42391303
# Probabilitas : [0.1965812 ,0.1965812 ,0.1965812 ,0.01709402,0.1965812 ,0.1965812 ]
# Probabilitas Paling Tinggi : 0.19658119976520538, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [7,8,0,2]
#
#
# GENERASI [14] ------
# CHROMOSOME 0 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 1 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 2 : [7,8,0,2], fitness = 0.5
# CHROMOSOME 3 : [7,8,3,2], fitness = 0.09090909090909091
# CHROMOSOME 4 : [6,8,0,2], fitness = 1.0
# CHROMOSOME 5 : [7,8,0,2], fitness = 0.5
# FITNESS SELESAI!!
# [ 1  1  1 10  0  1]
# Total fitness : 3.090909
# Rata-rata fitness : 0.5151515
# Probabilitas : [0.16176471,0.16176471,0.16176471,0.02941177,0.32352942,0.16176471]
# Probabilitas Paling Tinggi : 0.3235294222831726, Pada chromosome ke 4
# CHROMOSOME YANG MUNGKIN TERPILIH : [6,8,0,2]
#
#
# ----------------------------------------------------------------------
# ALL DONE!
# CHROMOSOME TERTINGGI DAN TERBAIK ADALAH
# [6 8 0 2]
